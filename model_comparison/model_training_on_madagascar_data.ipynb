# %%
#mainly based based on https://github.com/Diyago/ML-DL-scripts/tree/master/DEEP%20LEARNING/segmentation/Segmentation%20pipeline

# %%
IMAGE_SIZE = (512, 512)
NUMBER_OF_FOLDS = 5
NUMBER_OF_EPOCHS = 100
STARTING_FOLD = 1#  1 the first fold (not 0)

# %%
HOME = r"/content/drive/MyDrive/gather/ML-DL-scripts/DEEP LEARNING/segmentation/Segmentation pipeline"
req_file = (HOME + r"/requirementstf1.15V3.txt")
print(req_file)
#!pip install -r "$req_file"   --use-deprecated=legacy-resolver  #if needed install packages

# %% [markdown]
# # Preparing Libraries and Folders

# %%
# %tensorflow_version 1.15
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
import os
os.chdir(HOME)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.15`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
import numpy as np
from tensorflow.keras.utils import Sequence
#from keras.utils import Sequence
from skimage.io import imread
import os
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
import tensorflow as tf
from model_training import *
import pandas as pd

from albumentations import Resize

tf.logging.set_verbosity(tf.logging.ERROR)
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
from albumentations import (
    Blur, Compose, HorizontalFlip, HueSaturationValue,
                            IAAEmboss,
                           IAASharpen, JpegCompression, OneOf,
                            RandomBrightness, RandomBrightnessContrast,
                            RandomContrast, RandomCrop, RandomGamma,
                            RandomRotate90, RGBShift, ShiftScaleRotate,
                            Transpose, VerticalFlip, ElasticTransform, GridDistortion, OpticalDistortion
                            )
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Defining data generator

# %%
class DataGeneratorFolder(Sequence):
    def __init__(self, root_dir=r'../data/val_test', image_folder='img/', mask_folder='masks/', 
                 batch_size=1, image_size=256, nb_y_features=1, 
                 augmentation=None,
                 suffle=True, image_names = None, fold_number = None):
      
        self.root_dir = root_dir
        self.image_folder = image_folder
        self.mask_folder = mask_folder

        self.image_filenames = sorted(os.listdir(os.path.join(root_dir, image_folder)))
        self.mask_names = sorted(os.listdir(os.path.join(root_dir, mask_folder))) 
        self.fold_number = fold_number

        if not image_names is None:
          self.image_filenames = pd.Series(self.image_filenames)
          self.image_filenames = list(self.image_filenames[pd.Series(self.image_filenames).isin(image_names)])
          self.mask_names = self.image_filenames
        
        self.batch_size = batch_size
        self.currentIndex = 0
        self.augmentation = augmentation
        self.image_size = image_size
        self.nb_y_features = nb_y_features
        self.indexes = None
        self.suffle = suffle
        
    def __len__(self):
        """
        Calculates size of batch
        """
        return int(np.ceil(len(self.image_filenames) / (self.batch_size)))

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.suffle==True:
            self.image_filenames, self.mask_names = shuffle(self.image_filenames, self.mask_names)
        
    def read_image_mask(self, image_name, mask_name, verbose = False):
        if verbose:
          print(image_name)
          print(mask_name)
        X_sample, y_sample = (imread(self.root_dir + "/" + self.image_folder +  "/" +  image_name)/255).astype("float32"), (imread(
            self.root_dir + "/" + self.mask_folder + "/" + mask_name, as_gray=True) > 0).astype(np.int8)
        if np.all(y_sample == 1):          
          if verbose: 
            print("probably different mask format, converting")          
          X_sample, y_sample = (imread(self.root_dir + "/" + self.image_folder +  "/" +  image_name)/255).astype("float32"), (imread(
            self.root_dir + "/" + self.mask_folder + "/" + mask_name, as_gray=True) > 0.50).astype(np.int8)
        return X_sample, y_sample

    def get_image_name_at_index(self, index):
      return self.image_filenames[index]

    def __getitem__(self, index, verbose=False):
        """
        Generate one batch of data
        
        """
        # Generate indexes of the batch
        data_index_min = int(index*self.batch_size)
        data_index_max = int(min((index+1)*self.batch_size, len(self.image_filenames)))
        
        indexes = self.image_filenames[data_index_min:data_index_max]

        this_batch_size = len(indexes) # The last batch can be smaller than the others
        
        # Defining dataset
        X = np.empty((this_batch_size, self.image_size, self.image_size, 3), dtype=np.float32)
        y = np.empty((this_batch_size, self.image_size, self.image_size, self.nb_y_features), dtype=np.uint8)
       
        for i, sample_index in enumerate(indexes):
            X_sample, y_sample = self.read_image_mask(self.image_filenames[index * self.batch_size + i], 
                                                    self.mask_names[index * self.batch_size + i], verbose)

            # if augmentation is defined, we assume its a train set
            if self.augmentation is not None:
                  
                # Augmentation code
                augmented = self.augmentation(self.image_size)(image=X_sample, mask=y_sample)
                image_augm = augmented['image']
                mask_augm = augmented['mask'].reshape(self.image_size, self.image_size, self.nb_y_features)
                X[i, ...] = np.clip(image_augm, a_min = 0, a_max=1)
                y[i, ...] = mask_augm
            
            # if augmentation isnt defined, we assume its a test set. 
            # Because test images can have different sizes we resize it to be divisable by 32
            elif self.augmentation is None and self.batch_size ==1:
                X_sample, y_sample = self.read_image_mask(self.image_filenames[index * 1 + i], 
                                                      self.mask_names[index * 1 + i], verbose)
                augmented = Resize(height=(X_sample.shape[0]//32)*32, width=(X_sample.shape[1]//32)*32)(image = X_sample, mask = y_sample)
                X_sample, y_sample = augmented['image'], augmented['mask']

                return X_sample.reshape(1, X_sample.shape[0], X_sample.shape[1], 3).astype(np.float32),\
                       y_sample.reshape(1, X_sample.shape[0], X_sample.shape[1], self.nb_y_features).astype(np.uint8)


        return X, y

# %%
test_generator = DataGeneratorFolder(root_dir = './road_segmentation/training',#'./data/road_segmentation_ideal/training',
                                     image_folder = 'input/', 
                                     mask_folder = 'output/',
                                     batch_size = 1,
                                     nb_y_features = 1, 
                                     #augmentation = aug_with_crop
                                     )
Xtest, ytest = test_generator.__getitem__(0)
plt.imshow(Xtest[0])     
plt.show()
plt.imshow(ytest[0, :,:,0])
plt.show()

# %%
from sklearn.model_selection import KFold
import os
IMAGE_FOLDER = './osm_data/images_256x256/images'
image_filenames = sorted(os.listdir(IMAGE_FOLDER))
X = range(0,len(image_filenames))
cv_outer = KFold(n_splits=NUMBER_OF_FOLDS, shuffle=True, random_state=1)
test_indexes_per_fold = {}
train_indexes_per_fold = {}
fold_number = 0


for train_ix, test_ix in cv_outer.split(X):
  fold_number = fold_number + 1

  train_indexes = []
  for train_index in train_ix:
    train_indexes.append(train_index)
  train_indexes_per_fold[fold_number] = train_indexes

  test_indexes = []
  for test_index in test_ix:
    test_indexes.append(test_index)
  test_indexes_per_fold[fold_number] = test_indexes

# %% [markdown]
# ## Callbacks

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

# reduces learning rate on plateau
lr_reducer = ReduceLROnPlateau(factor=0.1,
                               cooldown= 10,
                               patience=10,verbose =1,
                               min_lr=0.1e-5)
mode_autosave = ModelCheckpoint("./weights/road_crop.efficientnetb0imgsize.h5",monitor='val_iou_score', 
                                   mode = 'max', save_best_only=True, verbose=1, period =10)

# stop learining as metric on validatopn stop increasing
early_stopping = EarlyStopping(patience=10, verbose=1, mode = 'auto') 

# tensorboard for monitoring logs
tensorboard = TensorBoard(log_dir='./logs/tenboard', histogram_freq=0,
                          write_graph=True, write_images=False)

callbacks = [mode_autosave, lr_reducer, tensorboard, early_stopping]

# %%
def plot_training_history(history):
    """
    Plots model training history 
    """
    epoch = range(len(history["loss"]))
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(epoch, history["loss"], label="Train loss")
    ax_loss.plot(epoch, history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(epoch, history["iou_score"], label="Train iou")
    ax_acc.plot(epoch, history["val_iou_score"], label="Validation iou")
    ax_acc.legend()

# %%
from segmentation_models import Unet
from keras.optimizers import Adam
from segmentation_models.losses import bce_jaccard_loss, bce_dice_loss
from segmentation_models.metrics import iou_score
from keras.models import load_model
import random
import pickle


model = Unet(backbone_name = 'efficientnetb0', encoder_weights='imagenet', encoder_freeze = False)
model.compile(optimizer = Adam(),
                    loss=bce_jaccard_loss, metrics=[iou_score])
TRAIN_AGAIN = True
if TRAIN_AGAIN:    
  for current_fold_number in range(STARTING_FOLD, NUMBER_OF_FOLDS+1):
    print(f"current fold: {current_fold_number}")    
    batch_size = 4 
    

    from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard

    # reduces learning rate on plateau
    lr_reducer = ReduceLROnPlateau(factor=0.1,
                                  cooldown= 10,
                                  patience=10,verbose =1,
                                  min_lr=0.1e-5)
    mode_autosave = ModelCheckpoint("./weights/road_crop.efficientnetb0imgsize.h5",monitor='val_iou_score', 
                                      mode = 'max', save_best_only=True, verbose=1, period =10)

    # stop learining as metric on validatopn stop increasing
    early_stopping = EarlyStopping(patience=10, verbose=1, mode = 'auto') 

    # tensorboard for monitoring logs
    tensorboard = TensorBoard(log_dir='./logs/tenboard', histogram_freq=0,
                              write_graph=True, write_images=False)

    callbacks = [mode_autosave, lr_reducer, tensorboard, early_stopping]

    k = len(train_indexes_per_fold[current_fold_number])*0.8

    random.seed(1)
    train_indexes_for_loss = sorted(random.sample(train_indexes_per_fold[current_fold_number], int(k)))
    validation_indexes = sorted(list(set(train_indexes_per_fold[current_fold_number]).difference(train_indexes_for_loss)))


    train_generator = DataGeneratorFolder(root_dir = './osm_data',#'./data/road_segmentation_ideal/training',
                                        image_folder = 'images_256x256/images', 
                                        #mask_folder = 'masks_256x256/masks',
                                      mask_folder = 'masks_256x256/masks',
                                      augmentation = aug_with_crop,
                                        batch_size = batch_size,
                                        nb_y_features = 1, 
                                          image_size=IMAGE_SIZE[0],
                                        #augmentation = aug_with_crop
                                          image_names = pd.Series(image_filenames).iloc[train_indexes_for_loss],
                                          fold_number = current_fold_number
                                        )

    test_generator  = DataGeneratorFolder(root_dir = './osm_data',#'./data/road_segmentation_ideal/training',
                                        image_folder = 'images_256x256/images', 
                                        #mask_folder = 'masks_256x256/masks',
                                      mask_folder = 'masks_256x256/masks',
                                        batch_size = 1,
                                        nb_y_features = 1, 
                                          image_names = pd.Series(image_filenames).iloc[validation_indexes],
                                          fold_number = current_fold_number
                                        #augmentation = aug_with_crop
                                        )
    model = Unet(backbone_name = 'efficientnetb0', encoder_weights='imagenet', encoder_freeze = False)
    model.compile(optimizer = Adam(),
                    loss=bce_jaccard_loss, metrics=[iou_score])

    history = model.fit_generator(train_generator, shuffle =True,
                      epochs=NUMBER_OF_EPOCHS, workers=30, use_multiprocessing=True,
                      validation_data = test_generator, 
                      verbose = 1, callbacks=callbacks)  
    plot_training_history(history.history)
    model.save(f"cached_intermediate_data/model_madagascar_fold{current_fold_number}.h5")
    with open(f'cached_intermediate_data/history_madagascar_fold{current_fold_number}.pickle', 'wb') as file_pi:
        pickle.dump(history.history, file_pi)
  else:    
    model = load_model('model_short.h5', compile=False)
# Out:
# current fold: 1
# Epoch 1/100
# 88/88 [==============================] - 75s 857ms/step - loss: 1.2392 - iou_score: 0.0287 - val_loss: 1.2824 - val_iou_score: 0.0282
# Epoch 2/100
# 88/88 [==============================] - 54s 619ms/step - loss: 1.0893 - iou_score: 0.0544 - val_loss: 1.1201 - val_iou_score: 0.0881
# Epoch 3/100
# 88/88 [==============================] - 58s 657ms/step - loss: 1.0596 - iou_score: 0.0866 - val_loss: 1.0360 - val_iou_score: 0.1010
# Epoch 4/100
# 88/88 [==============================] - 56s 637ms/step - loss: 1.0483 - iou_score: 0.0983 - val_loss: 0.9862 - val_iou_score: 0.1395
# Epoch 5/100
# 88/88 [==============================] - 57s 652ms/step - loss: 1.0318 - iou_score: 0.1131 - val_loss: 1.1503 - val_iou_score: 0.1365
# Epoch 6/100
# 88/88 [==============================] - 57s 649ms/step - loss: 1.0343 - iou_score: 0.1106 - val_loss: 1.0895 - val_iou_score: 0.1426
# Epoch 7/100
# 88/88 [==============================] - 56s 636ms/step - loss: 1.0316 - iou_score: 0.1126 - val_loss: 0.8918 - val_iou_score: 0.1413
# Epoch 8/100
# Epoch 7/100
# 88/88 [==============================] - 57s 644ms/step - loss: 1.0261 - iou_score: 0.1185 - val_loss: 0.9591 - val_iou_score: 0.1479
# Epoch 9/100
# 88/88 [==============================] - 57s 651ms/step - loss: 1.0151 - iou_score: 0.1257 - val_loss: 0.9939 - val_iou_score: 0.1522
# Epoch 10/100
# 88/88 [==============================] - 57s 644ms/step - loss: 1.0212 - iou_score: 0.1222 - val_loss: 1.0037 - val_iou_score: 0.1576
#
# Epoch 00010: val_iou_score improved from -inf to 0.15759, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 11/100
# 88/88 [==============================] - 54s 610ms/step - loss: 1.0174 - iou_score: 0.1261 - val_loss: 1.0409 - val_iou_score: 0.1599
# Epoch 12/100
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0272 - iou_score: 0.1143 - val_loss: 1.0086 - val_iou_score: 0.1686
# Epoch 13/100
# 88/88 [==============================] - 58s 660ms/step - loss: 1.0133 - iou_score: 0.1293 - val_loss: 0.9088 - val_iou_score: 0.1283
# Epoch 14/100
# 88/88 [==============================] - 57s 653ms/step - loss: 1.0114 - iou_score: 0.1316 - val_loss: 0.8691 - val_iou_score: 0.1672
# Epoch 15/100
# 88/88 [==============================] - 58s 663ms/step - loss: 1.0116 - iou_score: 0.1299 - val_loss: 1.0583 - val_iou_score: 0.1603
# Epoch 16/100
# 88/88 [==============================] - 57s 647ms/step - loss: 1.0105 - iou_score: 0.1313 - val_loss: 0.9175 - val_iou_score: 0.1586
# Epoch 17/100
# 88/88 [==============================] - 57s 644ms/step - loss: 1.0068 - iou_score: 0.1365 - val_loss: 1.1106 - val_iou_score: 0.1711
# Epoch 18/100
# Epoch 17/100
# 88/88 [==============================] - 59s 667ms/step - loss: 1.0153 - iou_score: 0.1272 - val_loss: 1.0360 - val_iou_score: 0.1694
# Epoch 19/100
# 88/88 [==============================] - 57s 650ms/step - loss: 1.0150 - iou_score: 0.1283 - val_loss: 1.0687 - val_iou_score: 0.1625
# Epoch 20/100
# Epoch 19/100
# 88/88 [==============================] - 58s 655ms/step - loss: 1.0118 - iou_score: 0.1284 - val_loss: 0.9248 - val_iou_score: 0.1674
#
# Epoch 00020: val_iou_score improved from 0.15759 to 0.16739, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 21/100
# 88/88 [==============================] - 54s 614ms/step - loss: 1.0010 - iou_score: 0.1392 - val_loss: 1.0629 - val_iou_score: 0.1740
# Epoch 22/100
# 88/88 [==============================] - 59s 667ms/step - loss: 1.0052 - iou_score: 0.1363 - val_loss: 0.9951 - val_iou_score: 0.1735
# Epoch 23/100
# 88/88 [==============================] - 59s 666ms/step - loss: 1.0111 - iou_score: 0.1304 - val_loss: 0.8944 - val_iou_score: 0.1672
# Epoch 24/100
# 88/88 [==============================] - 57s 653ms/step - loss: 1.0041 - iou_score: 0.1381 - val_loss: 0.8552 - val_iou_score: 0.1638
# Epoch 25/100
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0029 - iou_score: 0.1375 - val_loss: 0.8500 - val_iou_score: 0.1691
# Epoch 26/100
# Epoch 25/100
# 88/88 [==============================] - 58s 656ms/step - loss: 1.0009 - iou_score: 0.1401 - val_loss: 0.9134 - val_iou_score: 0.1669
# Epoch 27/100
# 88/88 [==============================] - 58s 662ms/step - loss: 0.9990 - iou_score: 0.1410 - val_loss: 0.9350 - val_iou_score: 0.1574
# Epoch 28/100
# 88/88 [==============================] - 57s 651ms/step - loss: 1.0047 - iou_score: 0.1364 - val_loss: 0.8474 - val_iou_score: 0.1685
# Epoch 29/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.0075 - iou_score: 0.1337Epoch 29/100
# 88/88 [==============================] - 57s 653ms/step - loss: 1.0086 - iou_score: 0.1326 - val_loss: 1.0527 - val_iou_score: 0.1741
# Epoch 30/100
# 88/88 [==============================] - 56s 637ms/step - loss: 1.0113 - iou_score: 0.1289 - val_loss: 0.9429 - val_iou_score: 0.1644
# Epoch 30/100
#
# Epoch 00030: val_iou_score did not improve from 0.16739
# Epoch 31/100
# 87/88 [============================>.] - ETA: 0s - loss: 0.9925 - iou_score: 0.1495Epoch 31/100
# 88/88 [==============================] - 58s 658ms/step - loss: 0.9918 - iou_score: 0.1496 - val_loss: 0.9497 - val_iou_score: 0.1683
# Epoch 32/100
# 88/88 [==============================] - 58s 657ms/step - loss: 1.0040 - iou_score: 0.1388 - val_loss: 0.9296 - val_iou_score: 0.1861
# Epoch 33/100
# 88/88 [==============================] - 58s 658ms/step - loss: 1.0048 - iou_score: 0.1362 - val_loss: 1.0055 - val_iou_score: 0.1716
# Epoch 34/100
# 88/88 [==============================] - 57s 653ms/step - loss: 1.0021 - iou_score: 0.1396 - val_loss: 0.8688 - val_iou_score: 0.1603
# Epoch 35/100
# 88/88 [==============================] - 58s 655ms/step - loss: 0.9909 - iou_score: 0.1474 - val_loss: 0.9829 - val_iou_score: 0.1643
# Epoch 36/100
# 88/88 [==============================] - 58s 660ms/step - loss: 1.0003 - iou_score: 0.1394 - val_loss: 1.0599 - val_iou_score: 0.1700
# Epoch 37/100
# 88/88 [==============================] - 57s 645ms/step - loss: 0.9853 - iou_score: 0.1526 - val_loss: 0.8920 - val_iou_score: 0.1670
# Epoch 38/100
# 88/88 [==============================] - 58s 658ms/step - loss: 0.9906 - iou_score: 0.1494 - val_loss: 1.1080 - val_iou_score: 0.1674
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 00038: early stopping
# current fold: 2
# Epoch 1/100
# 88/88 [==============================] - 72s 822ms/step - loss: 1.1727 - iou_score: 0.0358 - val_loss: 1.3366 - val_iou_score: 0.0538
# Epoch 2/100
# 88/88 [==============================] - 56s 631ms/step - loss: 1.0640 - iou_score: 0.0814 - val_loss: 0.9837 - val_iou_score: 0.1133
# Epoch 3/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.0516 - iou_score: 0.0966 - 56s 631ms/step - loss: 1.0640 - iou_score: 0.0814 - val_loss: 0.9837 - val_iou_score: 0.1133
# 88/88 [==============================] - 59s 666ms/step - loss: 1.0509 - iou_score: 0.0967 - val_loss: 0.8393 - val_iou_score: 0.1421
# Epoch 4/100
# 88/88 [==============================] - 56s 641ms/step - loss: 1.0406 - iou_score: 0.1055 - val_loss: 1.0055 - val_iou_score: 0.1461
# Epoch 5/100
# 88/88 [==============================] - 59s 669ms/step - loss: 1.0371 - iou_score: 0.1120 - val_loss: 1.0390 - val_iou_score: 0.1599
# Epoch 6/100
# 88/88 [==============================] - 59s 671ms/step - loss: 1.0336 - iou_score: 0.1115 - val_loss: 1.0409 - val_iou_score: 0.1605
# Epoch 7/100
# 88/88 [==============================] - 60s 680ms/step - loss: 1.0291 - iou_score: 0.1171 - val_loss: 1.0221 - val_iou_score: 0.1588
# Epoch 8/100
# 88/88 [==============================] - 57s 645ms/step - loss: 1.0242 - iou_score: 0.1214 - val_loss: 1.1073 - val_iou_score: 0.1627
# Epoch 8/100
# Epoch 9/100
# 88/88 [==============================] - 58s 660ms/step - loss: 1.0270 - iou_score: 0.1203 - val_loss: 1.0126 - val_iou_score: 0.1669
# Epoch 10/100
# 88/88 [==============================] - 58s 663ms/step - loss: 1.0177 - iou_score: 0.1273 - val_loss: 1.0739 - val_iou_score: 0.1660
#
# Epoch 00010: val_iou_score improved from -inf to 0.16605, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 11/100
# 88/88 [==============================] - 56s 637ms/step - loss: 1.0221 - iou_score: 0.1236 - val_loss: 1.0329 - val_iou_score: 0.1657
# Epoch 12/100
# 88/88 [==============================] - 59s 675ms/step - loss: 1.0166 - iou_score: 0.1281 - val_loss: 1.0042 - val_iou_score: 0.1703
# Epoch 13/100
# 88/88 [==============================] - 58s 664ms/step - loss: 1.0210 - iou_score: 0.1260 - val_loss: 1.0114 - val_iou_score: 0.1720
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 00013: early stopping
# current fold: 3
# Epoch 1/100
# 88/88 [==============================] - 74s 843ms/step - loss: 1.2993 - iou_score: 0.0302 - val_loss: 1.3763 - val_iou_score: 0.0316
# Epoch 2/100
# 88/88 [==============================] - 57s 646ms/step - loss: 1.0924 - iou_score: 0.0546 - val_loss: 1.2955 - val_iou_score: 0.0701
# Epoch 3/100
# 88/88 [==============================] - 61s 694ms/step - loss: 1.0565 - iou_score: 0.0860 - val_loss: 1.0812 - val_iou_score: 0.1078
# Epoch 4/100
# Epoch 3/100
# 88/88 [==============================] - 60s 680ms/step - loss: 1.0437 - iou_score: 0.1014 - val_loss: 1.1675 - val_iou_score: 0.1226
# Epoch 5/100
# 88/88 [==============================] - 60s 682ms/step - loss: 1.0357 - iou_score: 0.1093 - val_loss: 1.0863 - val_iou_score: 0.1352
# Epoch 6/100
# 88/88 [==============================] - 59s 670ms/step - loss: 1.0322 - iou_score: 0.1133 - val_loss: 1.0069 - val_iou_score: 0.1464
# Epoch 7/100
# 88/88 [==============================] - 60s 678ms/step - loss: 1.0344 - iou_score: 0.1107 - val_loss: 0.9647 - val_iou_score: 0.1614
# Epoch 8/100
# 88/88 [==============================] - 58s 665ms/step - loss: 1.0340 - iou_score: 0.1091 - val_loss: 0.8543 - val_iou_score: 0.1531
# Epoch 9/100
# 88/88 [==============================] - 61s 690ms/step - loss: 1.0282 - iou_score: 0.1158 - val_loss: 0.9721 - val_iou_score: 0.1538
# Epoch 10/100
# 88/88 [==============================] - 60s 680ms/step - loss: 1.0244 - iou_score: 0.1202 - val_loss: 0.9592 - val_iou_score: 0.1401
#
# Epoch 00010: val_iou_score improved from -inf to 0.14013, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 11/100
# 88/88 [==============================] - 56s 637ms/step - loss: 1.0231 - iou_score: 0.1192 - val_loss: 0.8204 - val_iou_score: 0.1497
# Epoch 12/100
# 88/88 [==============================] - 61s 692ms/step - loss: 1.0232 - iou_score: 0.1208 - val_loss: 1.0127 - val_iou_score: 0.1595
# Epoch 13/100
# 88/88 [==============================] - 59s 676ms/step - loss: 1.0141 - iou_score: 0.1283 - val_loss: 0.9798 - val_iou_score: 0.1543
# Epoch 14/100
# 87/88 [============================>.] - ETA: 0s - loss: 1.0150 - iou_score: 0.1279Epoch 14/100
# 88/88 [==============================] - 60s 678ms/step - loss: 1.0147 - iou_score: 0.1282 - val_loss: 0.9161 - val_iou_score: 0.1690
# Epoch 15/100
# 88/88 [==============================] - 59s 670ms/step - loss: 1.0153 - iou_score: 0.1287 - val_loss: 0.9365 - val_iou_score: 0.1488
# Epoch 16/100
# 88/88 [==============================] - 60s 683ms/step - loss: 1.0175 - iou_score: 0.1234 - val_loss: 0.8013 - val_iou_score: 0.1581
# Epoch 17/100
# 88/88 [==============================] - 60s 677ms/step - loss: 1.0213 - iou_score: 0.1238 - val_loss: 1.0074 - val_iou_score: 0.1523
# Epoch 18/100
# 88/88 [==============================] - 61s 691ms/step - loss: 1.0187 - iou_score: 0.1253 - val_loss: 0.9957 - val_iou_score: 0.1424
# Epoch 18/100
# Epoch 19/100
# 88/88 [==============================] - 59s 672ms/step - loss: 1.0108 - iou_score: 0.1309 - val_loss: 0.9838 - val_iou_score: 0.1695
# Epoch 20/100
# 88/88 [==============================] - 60s 685ms/step - loss: 1.0119 - iou_score: 0.1314 - val_loss: 1.2182 - val_iou_score: 0.1428
#
# Epoch 00020: val_iou_score improved from 0.14013 to 0.14279, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 21/100
# 88/88 [==============================] - 56s 639ms/step - loss: 1.0087 - iou_score: 0.1325 - val_loss: 1.1115 - val_iou_score: 0.1660
# Epoch 22/100
# 88/88 [==============================] - 61s 692ms/step - loss: 1.0075 - iou_score: 0.1354 - val_loss: 1.1027 - val_iou_score: 0.1614
# Epoch 23/100
# 88/88 [==============================] - 60s 680ms/step - loss: 1.0092 - iou_score: 0.1326 - val_loss: 1.0039 - val_iou_score: 0.1646
# Epoch 24/100
# 88/88 [==============================] - 59s 665ms/step - loss: 1.0038 - iou_score: 0.1375 - val_loss: 0.9431 - val_iou_score: 0.1834
# Epoch 25/100
# 88/88 [==============================] - 60s 681ms/step - loss: 0.9997 - iou_score: 0.1406 - val_loss: 0.9932 - val_iou_score: 0.1545
# Epoch 26/100
# 88/88 [==============================] - 61s 692ms/step - loss: 1.0130 - iou_score: 0.1315 - val_loss: 1.0113 - val_iou_score: 0.1549
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 00026: early stopping
# current fold: 4
# Epoch 1/100
# 88/88 [==============================] - 78s 883ms/step - loss: 1.1733 - iou_score: 0.0403 - val_loss: 1.5427 - val_iou_score: 0.0457
# Epoch 2/100
# 88/88 [==============================] - 59s 672ms/step - loss: 1.0681 - iou_score: 0.0836 - val_loss: 0.9874 - val_iou_score: 0.1181
# Epoch 3/100
# 88/88 [==============================] - 62s 700ms/step - loss: 1.0547 - iou_score: 0.0991 - val_loss: 1.0263 - val_iou_score: 0.1407
# Epoch 4/100
# 88/88 [==============================] - 61s 695ms/step - loss: 1.0400 - iou_score: 0.1102 - val_loss: 1.0434 - val_iou_score: 0.1412
# Epoch 5/100
# 88/88 [==============================] - 61s 697ms/step - loss: 1.0376 - iou_score: 0.1148 - val_loss: 1.0997 - val_iou_score: 0.1409
# Epoch 6/100
# 88/88 [==============================] - 60s 685ms/step - loss: 1.0348 - iou_score: 0.1182 - val_loss: 1.0011 - val_iou_score: 0.1261
# Epoch 6/100
# Epoch 7/100
# 88/88 [==============================] - 60s 679ms/step - loss: 1.0294 - iou_score: 0.1210 - val_loss: 0.9873 - val_iou_score: 0.1414
# Epoch 8/100
# 88/88 [==============================] - 60s 685ms/step - loss: 1.0337 - iou_score: 0.1177 - val_loss: 1.0086 - val_iou_score: 0.1400
# Epoch 9/100
# 88/88 [==============================] - 60s 686ms/step - loss: 1.0304 - iou_score: 0.1211 - val_loss: 1.0011 - val_iou_score: 0.1426
# Epoch 9/100Epoch 10/100
# 88/88 [==============================] - 60s 683ms/step - loss: 1.0218 - iou_score: 0.1273 - val_loss: 1.1063 - val_iou_score: 0.1432
#
# Epoch 00010: val_iou_score improved from -inf to 0.14319, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 11/100
# 88/88 [==============================] - 57s 651ms/step - loss: 1.0230 - iou_score: 0.1269 - val_loss: 1.0014 - val_iou_score: 0.1524
# Epoch 12/100
# 88/88 [==============================] - 62s 701ms/step - loss: 1.0239 - iou_score: 0.1275 - val_loss: 1.0706 - val_iou_score: 0.1356
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/100
# 88/88 [==============================] - 58s 661ms/step - loss: 1.0245 - iou_score: 0.1244 - val_loss: 1.0054 - val_iou_score: 0.1480
# Epoch 14/100
# 88/88 [==============================] - 61s 696ms/step - loss: 1.0168 - iou_score: 0.1296 - val_loss: 0.9634 - val_iou_score: 0.1516
# Epoch 15/100
# 88/88 [==============================] - 60s 685ms/step - loss: 1.0135 - iou_score: 0.1317 - val_loss: 0.8941 - val_iou_score: 0.1562
# Epoch 16/100
# Epoch 15/100
# 88/88 [==============================] - 62s 703ms/step - loss: 1.0171 - iou_score: 0.1307 - val_loss: 0.9425 - val_iou_score: 0.1577
# Epoch 17/100
# 88/88 [==============================] - 61s 695ms/step - loss: 1.0076 - iou_score: 0.1380 - val_loss: 1.0586 - val_iou_score: 0.1529
# Epoch 18/100
# 88/88 [==============================] - 61s 694ms/step - loss: 1.0107 - iou_score: 0.1369 - val_loss: 0.8796 - val_iou_score: 0.1592
# Epoch 19/100
# Epoch 18/100
# 88/88 [==============================] - 62s 704ms/step - loss: 1.0051 - iou_score: 0.1415 - val_loss: 0.8465 - val_iou_score: 0.1603
# Epoch 20/100
# 88/88 [==============================] - 62s 708ms/step - loss: 1.0077 - iou_score: 0.1398 - val_loss: 0.8892 - val_iou_score: 0.1540
#
# Epoch 00020: val_iou_score improved from 0.14319 to 0.15404, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 21/100
# 88/88 [==============================] - 59s 674ms/step - loss: 1.0029 - iou_score: 0.1424 - val_loss: 1.0039 - val_iou_score: 0.1518
# Epoch 22/100
# 88/88 [==============================] - 59s 674ms/step - loss: 1.0129 - iou_score: 0.1330 - val_loss: 0.9354 - val_iou_score: 0.1578
# Epoch 22/100
# Epoch 23/100
# 88/88 [==============================] - 60s 684ms/step - loss: 1.0069 - iou_score: 0.1394 - val_loss: 0.8620 - val_iou_score: 0.1607
# Epoch 24/100
# 88/88 [==============================] - 60s 681ms/step - loss: 1.0056 - iou_score: 0.1412 - val_loss: 0.9817 - val_iou_score: 0.1615
# Epoch 25/100
# 88/88 [==============================] - 63s 712ms/step - loss: 1.0002 - iou_score: 0.1469 - val_loss: 1.1121 - val_iou_score: 0.1602
# Epoch 26/100
# 88/88 [==============================] - 59s 674ms/step - loss: 1.0037 - iou_score: 0.1437 - val_loss: 0.9653 - val_iou_score: 0.1612
# Epoch 27/100
# 88/88 [==============================] - 61s 689ms/step - loss: 1.0087 - iou_score: 0.1380 - val_loss: 1.0089 - val_iou_score: 0.1579
# Epoch 28/100
# 88/88 [==============================] - 60s 686ms/step - loss: 1.0008 - iou_score: 0.1450 - val_loss: 1.0715 - val_iou_score: 0.1576
# Epoch 29/100
# 88/88 [==============================] - 59s 674ms/step - loss: 1.0039 - iou_score: 0.1436 - val_loss: 1.0564 - val_iou_score: 0.1587
# Epoch 00029: early stopping
# current fold: 5
# Epoch 1/100
# 88/88 [==============================] - 81s 915ms/step - loss: 1.1690 - iou_score: 0.0337 - val_loss: 1.3276 - val_iou_score: 0.0117
# Epoch 2/100
# 88/88 [==============================] - 59s 672ms/step - loss: 1.0712 - iou_score: 0.0772 - val_loss: 1.0632 - val_iou_score: 0.1107
# Epoch 3/100
# 88/88 [==============================] - 62s 701ms/step - loss: 1.0499 - iou_score: 0.0990 - val_loss: 0.8747 - val_iou_score: 0.1490
# Epoch 4/100
# 88/88 [==============================] - 62s 700ms/step - loss: 1.0444 - iou_score: 0.1044 - val_loss: 0.8703 - val_iou_score: 0.1588
# Epoch 5/100
# 88/88 [==============================] - 62s 700ms/step - loss: 1.0417 - iou_score: 0.1077 - val_loss: 1.0018 - val_iou_score: 0.1435
# Epoch 6/100
# 88/88 [==============================] - 61s 692ms/step - loss: 1.0312 - iou_score: 0.1146 - val_loss: 1.0548 - val_iou_score: 0.1488
# 88/88 [==============================] - 62s 700ms/step - loss: 1.0417 - iou_score: 0.1077 - val_loss: 1.0018 - val_iou_score: 0.1435
# Epoch 7/100
# 88/88 [==============================] - 61s 692ms/step - loss: 1.0240 - iou_score: 0.1227 - val_loss: 1.0309 - val_iou_score: 0.1662
# Epoch 8/100
# 88/88 [==============================] - 61s 697ms/step - loss: 1.0245 - iou_score: 0.1242 - val_loss: 0.9937 - val_iou_score: 0.1584
# Epoch 9/100
# 88/88 [==============================] - 61s 690ms/step - loss: 1.0213 - iou_score: 0.1243 - val_loss: 1.0034 - val_iou_score: 0.1606
# Epoch 10/100
# 88/88 [==============================] - 63s 711ms/step - loss: 1.0231 - iou_score: 0.1249 - val_loss: 1.0578 - val_iou_score: 0.1588
#
# Epoch 00010: val_iou_score improved from -inf to 0.15883, saving model to ./weights/road_crop.efficientnetb0imgsize.h5
# Epoch 11/100
# 88/88 [==============================] - 59s 672ms/step - loss: 1.0209 - iou_score: 0.1275 - val_loss: 1.0325 - val_iou_score: 0.1598
# Epoch 12/100
# 88/88 [==============================] - 61s 694ms/step - loss: 1.0194 - iou_score: 0.1269 - val_loss: 1.0263 - val_iou_score: 0.1543
# Epoch 13/100
# 88/88 [==============================] - 62s 706ms/step - loss: 1.0291 - iou_score: 0.1186 - val_loss: 1.1167 - val_iou_score: 0.1544
# Epoch 14/100
# Epoch 13/100
# 88/88 [==============================] - 62s 704ms/step - loss: 1.0190 - iou_score: 0.1257 - val_loss: 0.9266 - val_iou_score: 0.1603
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 00014: early stopping

# %%
#history = pickle.load(open(f'cached_intermediate_data/history_madagascar_fold{current_fold_number}.pickle', "rb"))
#plot_training_history(history)
